# %% [markdown]
# # Model Training

# %% [markdown]
# Run the complete training pipeline from the reusable source modules.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.train import train_pipeline
summary = train_pipeline(max_rows=120000, random_state=42)
summary

# %%
import pandas as pd
from src.utils import REPORTS_DIR
pd.read_csv(REPORTS_DIR / 'model_comparison.csv')

# %%
from IPython.display import Image, display
for image in ['confusion_matrix.png', 'precision_recall_curve.png', 'roc_curve.png']:
    display(Image(filename=str(REPORTS_DIR / image)))
